# %% [markdown]
# # histrogram

# %%
#A historgram shows the distribution of numerical data by:
# Dividing values into bins(ranges)
#COunting how many values fall itno each bin(frequesncy)
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)#seed sain hrr brr random value aayge
scores=np.random.normal(70,10,1000)#it follow the normal distribution(mean=70,standard deviation = 10,it genertae 1000 value
bins=[0,30,70,90,100]

# %%
plt.hist(scores,color="skyblue",edgecolor="black")
# Out:
# (array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.]),
#  array([39.53856945, 45.34406762, 51.14956579, 56.95506396, 62.76056213,
#         68.5660603 , 74.37155846, 80.17705663, 85.9825548 , 91.78805297,
#         97.59355114]),
#  <BarContainer object of 10 artists>)

# %%
#how to find useful information
plt.hist(scores,color="skyblue",edgecolor="black",bins=5)
plt.ylabel("no of students")
plt.xlabel("scores")
# Out:
# Text(0.5, 0, 'scores')

# %%
#we can changes bins value 
plt.hist(scores,color="skyblue",edgecolor="black",bins=20)
plt.ylabel("no of students")
plt.xlabel("scores")
##print(scores)
# Out:
# Text(0.5, 0, 'scores')

# %%
marks = [
    24,46,76,45,56,34,78,56,78,89,
    26,77,89,56,78,87,67,67,64,79,
    24,56,78,77,45,67,86,45,67,86
]
plt.hist(marks,color="skyblue",edgecolor="black",bins=bins)
plt.xlabel("Marks")
plt.ylabel("no.of students")
# Out:
# Text(0, 0.5, 'no.of students')

# %%
#HOW TO PLOT MULITPLE DATSET ON A SINGLE HISTROGRAM
# Multiple datasets
legit_transactions = [
    2.99, 5.49, 8.99, 12.50, 14.99, 19.99, 23.45, 29.99, 34.99, 39.50,
    45.00, 49.99, 55.25, 60.00, 75.99, 89.99, 120.50, 150.00, 199.99,
    249.99, 300.75, 450.00, 600.00, 850.00, 1200.00
]

fraud_transactions = [
    50, 100, 150, 200, 300, 500, 500, 750, 1000, 1000,
    1200, 1500, 1500, 2000, 2500, 3000, 3000
]
plt.hist(fraud_transactions, bins=10, label='Fraud', color='red', alpha=0.5, edgecolor="black")
plt.hist(legit_transactions, bins=10, label='Legit', color='green', alpha=0.5, edgecolor="black")

plt.xlabel('Transaction Amount ($)')
plt.ylabel('Frequency')
plt.title('Transaction Amount Distribution: Legitimate vs Fraudulent')
plt.legend()
plt.grid(True)

# %%
#Axvline
#axvline is used to draw a vertical refrence line on a plot,common 
#to mark cutoffs averages,pass averages,pass marks,or thresholds.
# axv line
marks = [
    25, 38, 42, 55, 61, 67, 72, 78, 83, 88,
    91, 95, 47, 53, 59, 64, 69, 74, 79, 85,
    92, 97, 33, 45, 58, 62, 71, 76, 81, 89
]

# custom bins
bins = [0, 30, 70, 90, 100]
plt.hist(
    marks,
    bins=bins,
    edgecolor="black",
    color="lightblue"
)

# line at passing marks - 33
plt.axvline(
    x=33,
    color="red",
    linestyle="--",
    linewidth=2,
    label="Pass Mark (33)"
)

plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.title("Distribution of Marks of 30 Students")
plt.grid(True)
